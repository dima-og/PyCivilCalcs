# %% [raw]
# ---
# title: "Calculation Test"
# format:
#   html:
#     toc: true
#     number-sections: true
#     colorlinks: true
#     documentclass: scrartcl
#     papersize: letter
#     mainfont: calibri
#     code-fold: true
#     page-layout: full
# execute:
#   echo: false
#   warning: false
#   message: false
# bibliography: references.bib
# ---
#
# \newpage

# %% [markdown]
# ### Calculate Column Stability

# %%
# --- 1) Import + reload (important when you edit the module) ---
import importlib
import re_lib.eng_var as ev

importlib.reload(ev)

# --- 2) Create environment ---
v = ev.EngEnv(eq_numbers=True, center_equations=True)  # defaults

# --- 3) Define variables (auto-displayed) ---
v.f_c = (4.0, "ksi", "Concrete compressive strength")
v.A_c = (200.0, "in^2", "Concrete area")
v.E = (29000, "ksi")
v.K = 1.0
v.L = (18, "ft")
v.r = (2.1, "in")
# Out:
# $\displaystyle \begin{aligned} & f_c = 4\,\mathrm{ksi}\;\;\text{(Concrete compressive strength)} \end{aligned}$
# $\displaystyle \begin{aligned} & A_c = 200\,\mathrm{in^2}\;\;\text{(Concrete area)} \end{aligned}$
# $\displaystyle \begin{aligned} & E = 29000\,\mathrm{ksi} \end{aligned}$
# $\displaystyle \begin{aligned} & K = 1 \end{aligned}$
# $\displaystyle \begin{aligned} & L = 18\,\mathrm{ft} \end{aligned}$
# $\displaystyle \begin{aligned} & r = 2.1\,\mathrm{in} \end{aligned}$

# %% [markdown]
# ***

# %%
# --- 4) Show a calc (prints once, returns a CalcExpr object) ---
P_D = v.show_calcs("P_D=(0.85*f_c*A_c)/2", out_units="kip", fmt=".2f")
# Re-show in different modes:
P_D.show_calcs(view="sym")   # only symbolic
P_D.show_calcs(view="num")   # substituted + result
P_D.show_calcs(view="full")  # symbolic + substituted + result
# Out:
# <div style='text-align:center;'>$$ P_D = \frac{0.85 \cdot A_{c} \cdot f_{c}}{2} = \frac{0.85 \cdot 200.00\,\mathrm{in^2} \cdot 4.00\,\mathrm{ksi}}{2} = 340.00\,\mathrm{kip}\qquad\text{(1)} $$</div>
# <div style='text-align:center;'>$$ P_D = \frac{0.85 \cdot A_{c} \cdot f_{c}}{2}\qquad\text{(2)} $$</div>
# <div style='text-align:center;'>$$ P_D = \frac{0.85 \cdot 200.00\,\mathrm{in^2} \cdot 4.00\,\mathrm{ksi}}{2} = 340.00\,\mathrm{kip}\qquad\text{(3)} $$</div>
# <div style='text-align:center;'>$$ P_D = \frac{0.85 \cdot A_{c} \cdot f_{c}}{2} = \frac{0.85 \cdot 200.00\,\mathrm{in^2} \cdot 4.00\,\mathrm{ksi}}{2} = 340.00\,\mathrm{kip}\qquad\text{(4)} $$</div>
# <Quantity(340.0, 'kip')>

# %% [markdown]
# ***

# %%
# --- 5) Get JUST the value (silent compute) ---
val = P_D.eval()            # pint Quantity
val_kip = val.to("kip")
val_mag = val_kip.magnitude # plain float
print(val)
print(val_kip)
print(val_mag)
# Out:
# 340.0 kip
# 340.0 kip
# 340.0

# %% [markdown]
# ***

# %%
# --- 6) Evaluate with overrides (does NOT mutate P_D; returns a new CalcExpr) ---
P2 = P_D(f_c=2*v.ksi, A_c=2*v.inch**2)
val2 = P2.eval().to("kip")
P2.show_calcs(view="full")
# Out:
# <div style='text-align:center;'>$$ P_D = \frac{0.85 \cdot A_{c} \cdot f_{c}}{2} = \frac{0.85 \cdot 2.00\,\mathrm{in^2} \cdot 2.00\,\mathrm{ksi}}{2} = 1.70\,\mathrm{kip}\qquad\text{(5)} $$</div>
# <Quantity(1.7, 'kip')>

# %% [markdown]
# ***

# %%
# --- 7) Optional equation numbering (semi-automatic) ---
v.reset_eq(0)

# Number this equation automatically:
P3 = v.show_calcs(
    "P_D=(0.85*f_c*A_c)/2",
    out_units="kip",
    fmt=".2f",
    number=True,
    tag="auto",          # (1), (2), ...
)

# Number + store a label (for your own lookup)
Fe = v.show_calcs(
    "F_e=math.pi**2*E/(K*L/r)**2",
    out_units="ksi",
    fmt=".3f",
    number=True,
    tag="@eq-fe",        # numbers it and stores label "eq-fe"
)
# Out:
# <div style='text-align:center;'>$$ P_D = \frac{0.85 \cdot A_{c} \cdot f_{c}}{2} = \frac{0.85 \cdot 200.00\,\mathrm{in^2} \cdot 4.00\,\mathrm{ksi}}{2} = 340.00\,\mathrm{kip}\qquad\text{(1)} $$</div>
# <div style='text-align:center;'>$$ F_e = \pi^{2} \cdot E \cdot \left(\frac{K \cdot L}{r}\right)^{- 2} = \pi^{2} \cdot 29000.000\,\mathrm{ksi} \cdot \left(\frac{1.000 \cdot 216.000\,\mathrm{in}}{2.100\,\mathrm{in}}\right)^{- 2} = 27.054\,\mathrm{ksi}\qquad\text{(2)} $$</div>

# %% [markdown]
# ***

# %%
# Lookup the number later:
n = v.eq("eq-fe")
v.render_equation(rf"\text{{Using Eq. ({n})}}", center=False)

# --- 8) Centering control per call ---
P_D.show_calcs(view="num", center=False)   # left-ish
P_D.show_calcs(view="num", center=True)    # centered
# Out:
# $\displaystyle \begin{aligned} & \text{Using Eq. (2)} \end{aligned}$
# $\displaystyle \begin{aligned} & P_D = \frac{0.85 \cdot 200.00\,\mathrm{in^2} \cdot 4.00\,\mathrm{ksi}}{2} = 340.00\,\mathrm{kip}\qquad\text{(3)} \end{aligned}$
# <div style='text-align:center;'>$$ P_D = \frac{0.85 \cdot 200.00\,\mathrm{in^2} \cdot 4.00\,\mathrm{ksi}}{2} = 340.00\,\mathrm{kip}\qquad\text{(4)} $$</div>
# <Quantity(340.0, 'kip')>

# %% [markdown]
# ***

# %%
cs.setup_concrete_section(v, fc_ksi=4.0, Ac_in2=200.0)

PD = cs.expr_PD(v)  # silent builder
val = PD(f_c=5*v.ksi, A_c=120*v.inch**2).eval()
PD.show_calcs(number=True, tag="auto")
# Out:
# $\displaystyle \begin{aligned} & f_c = 4\,\mathrm{ksi}\;\;\text{(Concrete compressive strength)} \end{aligned}$
# $\displaystyle \begin{aligned} & A_c = 200\,\mathrm{in^2}\;\;\text{(Concrete area)} \end{aligned}$
# <div style='text-align:center;'>$$ P_D = \frac{0.85 \cdot A_{c} \cdot f_{c}}{2} = \frac{0.85 \cdot 200.00\,\mathrm{in^2} \cdot 4.00\,\mathrm{ksi}}{2} = 340.00\,\mathrm{kip}\qquad\text{(5)} $$</div>
# <Quantity(340.0, 'kip')>

# %%
v = ev.EngEnv(eq_numbers=True, center_equations=True)

v.render_equation(r"\frac{1}{2}", center=True)    # centered
v.render_equation(r"\frac{1}{2}", center=False)   # left-ish
# Out:
# <div style='text-align:center;'>$$ \frac{1}{2} $$</div>
# $\displaystyle \begin{aligned} & \frac{1}{2} \end{aligned}$

# %%
import importlib
import re_lib.eng_var as ev
import re_lib.aci.concrete_section as mc

importlib.reload(ev)
importlib.reload(mc)

v = ev.EngEnv(eq_numbers=True, center_equations=True)

# Inputs (typical)
Mu = 250 * v.kip * v.ft
b  = 12  * v.inch
d  = 22  * v.inch
As = 4.0 * v.inch**2
fc = 4.0 * v.ksi
fy = 60  * v.ksi

res = mc.moment_check_rect_singly(
    v,
    Mu=Mu, b=b, d=d, As=As, fc=fc, fy=fy,
    reinforcement="tied",
    show=True,
    number=True,
    tag="auto",
    center=True,
)

# Value-only outputs if you need them later
res.ok, res.phi, res.ratio, res.phiMn.to("kip*ft")
# Out:
# $\displaystyle \begin{aligned} & M_u = 3000\,\mathrm{in·kip}\;\;\text{(Factored moment demand)} \end{aligned}$
# $\displaystyle \begin{aligned} & b = 12\,\mathrm{in}\;\;\text{(Section width)} \end{aligned}$
# $\displaystyle \begin{aligned} & d = 22\,\mathrm{in}\;\;\text{(Effective depth)} \end{aligned}$
# $\displaystyle \begin{aligned} & A_s = 4\,\mathrm{in^2}\;\;\text{(Tension steel area)} \end{aligned}$
# $\displaystyle \begin{aligned} & f_c = 4\,\mathrm{ksi}\;\;\text{(Concrete compressive strength)} \end{aligned}$
# $\displaystyle \begin{aligned} & f_y = 60\,\mathrm{ksi}\;\;\text{(Steel yield strength)} \end{aligned}$
# <div style='text-align:center;'>$$ \beta_1 = 0.85 $$</div>
# <div style='text-align:center;'>$$ a = \frac{A_{s} \cdot f_{y}}{0.85 \cdot b \cdot f_{c}} = \frac{4.000\,\mathrm{in^2} \cdot 60.000\,\mathrm{ksi}}{0.85 \cdot 12.000\,\mathrm{in} \cdot 4.000\,\mathrm{ksi}} = 5.882\,\mathrm{in}\qquad\text{(1)} $$</div>
# ...

# %%
v = ev.EngEnv(eq_numbers=False, center_equations=True)


v.V = (10, 'kip', 'Transverse shear force acting on the cross-section')
v.Q = (3, 'inch^3', ' First moment of area (or statical moment) of the cross-section area cut above the point of interest')
v.I = (9, 'inch^4', 'Moment of inertia')
q = v.show_calcs("q=(V*Q)/I", out_units="kip/in", fmt=".2f", tag=False,)
# Out:
# $\displaystyle \begin{aligned} & V = 10\,\mathrm{kip}\;\;\text{(Transverse shear force acting on the cross-section)} \end{aligned}$
# $\displaystyle \begin{aligned} & Q = 3\,\mathrm{in³}\;\;\text{( First moment of area (or statical moment) of the cross-section area cut above the point of interest)} \end{aligned}$
# $\displaystyle \begin{aligned} & I = 9\,\mathrm{in⁴}\;\;\text{(Moment of inertia)} \end{aligned}$
# $\displaystyle q = \frac{Q \cdot V}{I} = \frac{10.00\,\mathrm{kip} \cdot 3.00\,\mathrm{in³}}{9.00\,\mathrm{in⁴}} = 3.33\,\mathrm{kip/in}$
