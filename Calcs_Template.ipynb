# %% [raw]
# ---
# title: "Document Name"
# format:
#   pdf:
#     geometry:
#       - top=0.75in
#       - left=0.75in
#       - right=0.5in
#       - bottom=1in
#     toc: true
#     number-sections: true
#     colorlinks: true
#     documentclass: scrartcl
#     papersize: letter
#     mainfont: calibri
#     code-fold: true
#     page-layout: full
# execute:
#   echo: false
#   warning: false
#   message: false
#   output: asis
# bibliography: references.bib
# ---
# \newpage

# %%
#import libraries here
# --- 1) Import + reload (important when you edit the module) ---
import importlib
import re_lib.eng_var as ev


importlib.reload(ev)
# Out:
# <module 're_lib.eng_var' from 'C:\\Users\\dgolovichev\\Documents\\SynologyDrive\\Vibe_Coding\\PyCivilCalcs\\re_lib\\eng_var.py'>

# %% [markdown]
# ## General Information
#
# Introdactory text with figures as appropriate
#
# *Italic text* or _Italic text_
# **Bold text** or __Bold text__
#
#
# List:
# * Item 1
# * Item 2
#
# Numberred List:
# 1. Item 1
# 2. Item 2
#
# [Link](https://jupyter.org)
#
# `inline code`
#
# ***
#
#
# Inline: $y = a + bx$ renders as \(y=a+bx\).
#
# Display: $$P(A|B) = \frac{P(B|A)P(A)}{P(B)}$$ renders as a centered equation.
#
# Table 1.
# | Header 1 | Header 2 |
# | :--- | :--- |
# | Cell A | Cell B |
# | Cell C | Cell D |

# %% [markdown]
# ### Calcs Example (Engineering Workflow)
# This example shows a practical structural workflow:
# 1. Define equations first (`v.eq.*`) so formulas are reusable and report-ready.
# 2. Define variables with units/comments.
# 3. Display symbolic, numeric, and full formatted equations.
# 4. Control numbering/alignment and extract plain numeric values for downstream checks.

# %%
# --- 2) Create environment ---
v = ev.EngEnv(
    eq_numbers=True,
    center_equations=True,
    output='notebook',
    notebook_render_mode='html',   # use 'latex' for pure MathJax mode
)

# --- 3) Define reusable equations first ---
v.eq.a = '(A_s*f_y)/(0.85*b*f_c)'
v.eq.phiM_n = 'phi*(A_s*f_y*(d-a/2))'
v.eq.DCR = 'M_u/phiM_n'

# %%
# --- 4) Define variables (with units + comments) ---
v.phi = (0.90, '', 'Strength reduction factor')
v.A_s = (4.00, 'in^2', 'Tension steel area')
v.f_y = (60.0, 'ksi', 'Steel yield strength')
v.b   = (12.0, 'in',  'Section width')
v.f_c = (4.00, 'ksi', 'Concrete compressive strength')
v.d   = (22.0, 'in',  'Effective depth')
v.M_u = (250.0, 'kip*ft', 'Factored moment demand')

# show a single variable on demand
v.A_s.show()
# Out:
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# \phi &= 0.9\;\;\text{(Strength reduction factor)}
# \end{aligned}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# A_{s} &= 4\,\mathrm{in^2}\;\;\text{(Tension steel area)}
# \end{aligned}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# f_{y} &= 60\,\mathrm{ksi}\;\;\text{(Steel yield strength)}
# \end{aligned}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# b &= 12\,\mathrm{in}\;\;\text{(Section width)}
# \end{aligned}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# f_{c} &= 4\,\mathrm{ksi}\;\;\text{(Concrete compressive strength)}
# \end{aligned}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# d &= 22\,\mathrm{in}\;\;\text{(Effective depth)}
# \end{aligned}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# M_{u} &= 250\,\mathrm{ft·kip}\;\;\text{(Factored moment demand)}
# \end{aligned}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# A_{s} &= 4\,\mathrm{in^2}\;\;\text{(Tension steel area)}
# \end{aligned}
# $$</div>

# %%
# --- 5) Show equation formatting modes ---
# symbolic only
v.eq.a.show(view='sym', number=True, center=False)

# numeric substitution + result
v.a = v.eq.a.show(view='num', out_units='in', fmt='.4f', number=True, center=False)
v.a.units = 'in'

# full: symbolic + substitution + result
v.eq.phiM_n.show(view='full', out_units='kip*ft', fmt='.3f', number=True, center=False)
# Out:
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# a &= \frac{A_{s} \cdot f_{y}}{0.85 \cdot b \cdot f_{c}}\qquad\text{(6)}
# \end{aligned}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# a &= \frac{\left(4.0000\,\mathrm{in^2}\right) \cdot \left(60.0000\,\mathrm{ksi}\right)}{0.85 \cdot \left(12.0000\,\mathrm{in}\right) \cdot \left(4.0000\,\mathrm{ksi}\right)} = 5.8824\,\mathrm{in}\qquad\text{(7)}
# \end{aligned}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# a &= 5.88235\,\mathrm{in}
# \end{aligned}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# \phi M_{n} &= \phi \cdot A_{s} \cdot f_{y} \cdot \left(d - \frac{a}{2}\right) = \left(0.900\right) \cdot \left(4.000\,\mathrm{in^2}\right) \cdot \left(60.000\,\mathrm{ksi}\right) \cdot \left(\left(22.000\,\mathrm{in}\right) - \frac{\left(5.882\,\mathrm{in}\right)}{2}\right) = 343.059\,\mathrm{ft·kip}\qquad\text{(8)}
# \end{aligned}
# $$</div>
# <Quantity(343.058824, 'kip * foot')>

# %%
# --- 6) Default behavior: symbolic before variables, numeric after ---
tmp = ev.EngEnv(auto_display=False, eq_numbers=True)
tmp.eq.M_n = 'F_y*Z_x'

# No variables yet -> defaults to symbolic
tmp.eq.M_n.show(number=True)

tmp.F_y = (50, 'ksi')
tmp.Z_x = (100, 'in^3')

# Now all inputs exist -> defaults to numeric
tmp.eq.M_n.show(out_units='kip*in', number=True)
# Out:
# <div class='eng-center-eq' style='width:100%; text-align:center;'><style>.eng-center-eq .MathJax_Display{margin-left:auto !important; margin-right:auto !important; text-align:center !important;}.eng-center-eq mjx-container[display='true']{margin-left:auto !important; margin-right:auto !important; text-align:center !important;}</style>$$
# M_{n} = F_{y} \cdot Z_{x}\qquad\text{(1)}
# $$</div>
# <div class='eng-center-eq' style='width:100%; text-align:center;'><style>.eng-center-eq .MathJax_Display{margin-left:auto !important; margin-right:auto !important; text-align:center !important;}.eng-center-eq mjx-container[display='true']{margin-left:auto !important; margin-right:auto !important; text-align:center !important;}</style>$$
# M_{n} = \left(50\,\mathrm{ksi}\right) \cdot \left(100\,\mathrm{in³}\right) = 5000\,\mathrm{in·kip}\qquad\text{(2)}
# $$</div>
# <Quantity(5000.0, 'kip * inch')>

# %%
# --- 7) Numbering + labels ---
v.reset_eq(0)

v.eq.a.show(view='sym', number=True, tag='@eq-a')
v.eq.phiM_n.show(view='sym', number=True, tag='@eq-phiMn')

n_a = v.eq_label('eq-a')
n_phi = v.eq_label('eq-phiMn')
v.render_equation(rf"\text{{Use Eq. ({n_a}) in Eq. ({n_phi})}}", center=False)
# Out:
# <div class='eng-center-eq' style='width:100%; text-align:center;'><style>.eng-center-eq .MathJax_Display{margin-left:auto !important; margin-right:auto !important; text-align:center !important;}.eng-center-eq mjx-container[display='true']{margin-left:auto !important; margin-right:auto !important; text-align:center !important;}</style>$$
# a = \frac{A_{s} \cdot f_{y}}{0.85 \cdot b \cdot f_{c}}\qquad\text{(1)}
# $$</div>
# <div class='eng-center-eq' style='width:100%; text-align:center;'><style>.eng-center-eq .MathJax_Display{margin-left:auto !important; margin-right:auto !important; text-align:center !important;}.eng-center-eq mjx-container[display='true']{margin-left:auto !important; margin-right:auto !important; text-align:center !important;}</style>$$
# \phi M_{n} = \phi \cdot A_{s} \cdot f_{y} \cdot \left(d - \frac{a}{2}\right)\qquad\text{(2)}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# \text{Use Eq. (1) in Eq. (2)}
# \end{aligned}
# $$</div>

# %%
# --- 10) Unicode / Greek-friendly names ---
v.eq.define('ΔP', 'rho*g*h')
v.rho = (62.4, 'lbf/ft^3', 'Fluid unit weight')
v.g = (1.0, '', 'Normalized gravity factor')
v.h = (10.0, 'ft', 'Fluid head')

# Symbolic output with unicode equation name
v.eq['ΔP'].show(view='sym', number=True, center=False)
# Out:
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# \rho &= 62.4\,\mathrm{lbf/ft³}\;\;\text{(Fluid unit weight)}
# \end{aligned}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# g &= 1\;\;\text{(Normalized gravity factor)}
# \end{aligned}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# h &= 10\,\mathrm{ft}\;\;\text{(Fluid head)}
# \end{aligned}
# $$</div>
# <div class='eng-left-eq' style='width:100%; text-align:left;'><style>.eng-left-eq .MathJax_Display{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}.eng-left-eq mjx-container[display='true']{margin-left:0 !important; margin-right:auto !important; text-align:left !important;}</style>$$
# \begin{aligned}
# \DeltaP &= \rho \cdot g \cdot h\qquad\text{(5)}
# \end{aligned}
# $$</div>
